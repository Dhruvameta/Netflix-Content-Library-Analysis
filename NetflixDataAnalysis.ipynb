# %% [markdown]
# ****NETFLIX DATA ANALYSIS (csv FILE)****

# %%
import numpy as npa
import pandas as pd

# %% [markdown]
# **IMPORT CSV fILE**

# %%
df = pd.read_csv("Datasets/netflix_titles.csv")

# %% [markdown]
# **INSPECTING DATASETS**

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()  #some missig values exists.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %% [markdown]
# ***SELECTION OF DATA***

# %%
df["title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: str

# %%
df[['type', 'cast']]
# Out:
#          type                                               cast
# 0       Movie                                                NaN
# 1     TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3     TV Show                                                NaN
# 4     TV Show  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...       ...                                                ...
# 8802    Movie  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803  TV Show                                                NaN
# 8804    Movie  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Movie  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Movie  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %%
df[['type', 'cast']].size
# Out:
# 17614

# %%
df[['type','director','cast', 'country']]
# Out:
#          type         director  \
# 0       Movie  Kirsten Johnson
# 1     TV Show              NaN
# 2     TV Show  Julien Leclercq
# 3     TV Show              NaN
# 4     TV Show              NaN
# ...       ...              ...
# 8802    Movie    David Fincher
# 8803  TV Show              NaN
# 8804    Movie  Ruben Fleischer
# 8805    Movie     Peter Hewitt
# 8806    Movie      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# ...

# %%
df.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
df[df['type']=='Movie']
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[df['type']=='Movie'].shape
# Out:
# (6131, 12)

# %%
df[df['type']=='TV Show']
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['type']=='TV Show'].shape
# Out:
# (2676, 12)

# %%
df[df['type']=='TV Show'].info
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['release_year']>= 2020]
# Out:
#      show_id     type                                      title  \
# 0         s1    Movie                       Dick Johnson Is Dead
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# ...      ...      ...                                        ...
# 7594   s7595    Movie         Norm of the North: Family Vacation
# 8099   s8100    Movie                                Straight Up
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# ...

# %%
df[df['release_year']>= 2020].shape
# Out:
# (1545, 12)

# %%
df[(df['release_year']>= 2020) & (df['type']=='Movie')]
# Out:
#      show_id   type                               title  \
# 0         s1  Movie                Dick Johnson Is Dead
# 6         s7  Movie    My Little Pony: A New Generation
# 9        s10  Movie                        The Starling
# 12       s13  Movie                        Je Suis Karl
# 13       s14  Movie    Confessions of an Invisible Girl
# ...      ...    ...                                 ...
# 3046   s3047  Movie       All the Freckles in the World
# 3060   s3061  Movie                       Ghost Stories
# 5972   s5973  Movie                    #cats_the_mewvie
# 7594   s7595  Movie  Norm of the North: Family Vacation
# 8099   s8100  Movie                         Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# 6                         Robert Cullen, José Luis Ucha
# 9                                        Theodore Melfi
# 12                                  Christian Schwochow
# ...

# %%
movies_2020 = df[(df['release_year']>= 2020) & (df['type']=='Movie')].shape ## 794 movies released after 2020
print("number of Movies released after 2020: ", movies_2020)
# Out:
# number of Movies released after 2020:  (794, 12)

# %% [markdown]
# ***MISSING VALUES IN DATASET***

# %%
df.info  # THE INFO TELLS US THERE ARE MISSING VALUES IN CERTAIN NUMBER OF COLUMNS
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False) # Column named as DIRECTOR has the highest number of missing values
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
df.isna().sum().idxmax() # Name of the colummn with the  highest number of missing values
# Out:
# 'director'

# %%
df.dropna(subset=['country'])
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
df.dropna(subset=['country']).shape
# Out:
# (7976, 12)

# %%
df.sort_values(by='release_year',ascending=False) #NEWEST CONTENT
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df.sort_values(by='release_year',ascending=True) #OLDEST CONTENT
# Out:
#      show_id     type                               title  \
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# 8763   s8764    Movie     WWII: Report from the Aleutians
# ...      ...      ...                                 ...
# 3         s4  TV Show               Jailbirds New Orleans
# 2         s3  TV Show                           Ganglands
# 18       s19    Movie                           Intrusion
# 1         s2  TV Show                       Blood & Water
# 68       s69    Movie                          Schumacher
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %% [markdown]
# ***CREATING COLUMNS***

# %%
df["Recently_released"] = df["release_year"] >= 2020

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ***GROUPBY OPERATIONS***

# %%
df.groupby('type')['release_year'].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
df.groupby('country').size()
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Length: 748, dtype: int64

# %%
df.groupby('type').size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
df.groupby('type')['release_year'].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
df.groupby('rating')['title'].count()
# Out:
# rating
# 66 min         1
# 74 min         1
# 84 min         1
# G             41
# NC-17          3
# NR            80
# PG           287
# PG-13        490
# R            799
# TV-14       2160
# TV-G         220
# TV-MA       3207
# TV-PG        863
# TV-Y         307
# TV-Y7        334
# TV-Y7-FV       6
# UR             3
# Name: title, dtype: int64

# %%
df.groupby('country')['title'].count().sort_values(ascending=False).head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: title, dtype: int64

# %% [markdown]
# ***STRING OPERATIONS***

# %%
df['title'].str.upper()
# Out:
# 0        DICK JOHNSON IS DEAD
# 1               BLOOD & WATER
# 2                   GANGLANDS
# 3       JAILBIRDS NEW ORLEANS
# 4                KOTA FACTORY
#                 ...
# 8802                   ZODIAC
# 8803              ZOMBIE DUMB
# 8804               ZOMBIELAND
# 8805                     ZOOM
# 8806                   ZUBAAN
# Name: title, Length: 8807, dtype: str

# %%
df['title'].str.lower()
# Out:
# 0        dick johnson is dead
# 1               blood & water
# 2                   ganglands
# 3       jailbirds new orleans
# 4                kota factory
#                 ...
# 8802                   zodiac
# 8803              zombie dumb
# 8804               zombieland
# 8805                     zoom
# 8806                   zubaan
# Name: title, Length: 8807, dtype: str

# %%
df[df['title'].str.contains('love', case=False, na=False)]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %%
df[df['title'].str.contains(r'\bking\b', case=False, na=False)]
# Out:
#      show_id     type                                              title  \
# 73       s74    Movie                                       King of Boys
# 198     s199  TV Show               King of Boys: The Return of the King
# 291     s292  TV Show                                        SHAMAN KING
# 627     s628  TV Show                The Daily Life of the Immortal King
# 815     s816    Movie                                      The Girl King
# 1010   s1011    Movie                    Rudra: The Rise of King Pharaoh
# 2665   s2666  TV Show                          The King: Eternal Monarch
# 2794   s2795  TV Show                            The Letter for the King
# 2795   s2796  TV Show             Tiger King: Murder, Mayhem and Madness
# 3347   s3348    Movie                                           The King
# 3585   s3586  TV Show                                  The King's Avatar
# 3842   s3843    Movie                          Gatao 2: Rise of the King
# ...

# %%
df['director'].str.strip()
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: str

# %%
df.groupby('release_year').size().sort_values(ascending=False).head(1)
# Out:
# release_year
# 2018    1147
# dtype: int64

# %% [markdown]
# ***TOP 20 NEWEST RELEASED MOVIES OF INDIA***

# %%
df[df['country']=='India'].sort_values(by='release_year', ascending=False).head(20)
# Out:
#      show_id     type                 title  \
# 190     s191    Movie            Thimmarusu
# 909     s910    Movie             Milestone
# 4         s5  TV Show          Kota Factory
# 959     s960    Movie          The Disciple
# 918     s919  TV Show        Lava Ka Dhaava
# 297     s298  TV Show              Navarasa
# 903     s904    Movie               Nayattu
# 877     s878    Movie          Cinema Bandi
# 876     s877  TV Show          Alma Matters
# 735     s736    Movie               Sarbath
# 850     s851    Movie              99 Songs
# 871     s872    Movie    Sardar Ka Grandson
# 551     s552    Movie       Haseen Dillruba
# 1093   s1094  TV Show           The Big Day
# 1098   s1099    Movie               Mandela
# 1108   s1109    Movie                  Irul
# 1087   s1088    Movie                 Roohi
# 998     s999    Movie  Searching For Sheela
# 873     s874    Movie                 Ahaan
# 1037   s1038    Movie    Tuesdays & Fridays
#
# ...
